# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg  al  su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c   3   0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c   2   0  normal    normal  notpresent
# 2     4.000000  76.459948  a   1   0  normal    normal  notpresent
# 3     5.000000  76.459948  d   1   0  normal    normal  notpresent
# 4     5.000000  50.000000  c   0   0  normal    normal  notpresent
# ..         ...        ... ..  ..  ..     ...       ...         ...
# 394  51.492308  70.000000  a   0   0  normal    normal  notpresent
# 395  51.492308  70.000000  c   0   2  normal    normal  notpresent
# 396  51.492308  70.000000  c   3   0  normal    normal  notpresent
# 397  51.492308  90.000000  a   0   0  normal    normal  notpresent
# 398  51.492308  80.000000  a   0   0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#            age         bp  al  su         bgr          bu        sc  \
# 0     2.000000  76.459948   3   0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948   2   0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948   1   0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948   1   0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000   0   0  148.112676   25.000000  0.600000
# ..         ...        ...  ..  ..         ...         ...       ...
# 394  51.492308  70.000000   0   0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000   0   2  220.000000   68.000000  2.800000
# 396  51.492308  70.000000   3   0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000   0   0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000   0   0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# 0    137.528754  4.627244  12.518156  ...      False        False       False
# 1    137.528754  4.627244  10.700000  ...       True        False       False
# 2    138.000000  4.400000  12.000000  ...       True        False       False
# 3    138.000000  3.200000   8.100000  ...       True        False       False
# 4    137.528754  4.627244  11.800000  ...       True        False       False
# ..          ...       ...        ...  ...        ...          ...         ...
# 394  139.000000  3.700000  12.500000  ...       True        False       False
# 395  137.528754  4.627244   8.700000  ...       True        False       False
# 396  134.000000  2.700000   9.100000  ...       True        False       False
# 397  142.000000  5.500000   8.500000  ...       True        False       False
# 398  140.000000  5.000000  16.300000  ...       True        False       False
#
#      htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0      False   False    False       True    True    False                True
# 1      False   False    False       True   False    False                True
# 2      False   False    False       True   False    False                True
# 3      False   False    False       True   False     True                True
# 4      False   False    False       True   False    False                True
# ..       ...     ...      ...        ...     ...      ...                 ...
# 394    False   False    False       True   False    False                True
# 395     True    True    False       True   False     True                True
# 396     True    True    False      False   False    False                True
# 397     True    True    False       True   False     True                True
# 398    False   False    False       True   False    False               False
#
# [399 rows x 28 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp','al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c','sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present','htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']] 
dataset = dataset.astype(int)

# %%
independent
# Out:
#            age         bp  al  su         bgr          bu        sc  \
# 0     2.000000  76.459948   3   0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948   2   0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948   1   0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948   1   0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000   0   0  148.112676   25.000000  0.600000
# ..         ...        ...  ..  ..         ...         ...       ...
# 394  51.492308  70.000000   0   0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000   0   2  220.000000   68.000000  2.800000
# 396  51.492308  70.000000   3   0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000   0   0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000   0   0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  rbc_normal  pc_normal  pcc_present  \
# 0    137.528754  4.627244  12.518156  ...        True      False        False
# 1    137.528754  4.627244  10.700000  ...        True       True        False
# 2    138.000000  4.400000  12.000000  ...        True       True        False
# 3    138.000000  3.200000   8.100000  ...        True       True        False
# 4    137.528754  4.627244  11.800000  ...        True       True        False
# ..          ...       ...        ...  ...         ...        ...          ...
# 394  139.000000  3.700000  12.500000  ...        True       True        False
# 395  137.528754  4.627244   8.700000  ...        True       True        False
# 396  134.000000  2.700000   9.100000  ...        True       True        False
# 397  142.000000  5.500000   8.500000  ...        True       True        False
# 398  140.000000  5.000000  16.300000  ...        True       True        False
#
#      ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes
# 0         False    False   False    False       True    True    False
# 1         False    False   False    False       True   False    False
# 2         False    False   False    False       True   False    False
# 3         False    False   False    False       True   False     True
# 4         False    False   False    False       True   False    False
# ..          ...      ...     ...      ...        ...     ...      ...
# 394       False    False   False    False       True   False    False
# 395       False     True    True    False       True   False     True
# 396       False     True    True    False      False   False    False
# 397       False     True    True    False       True   False     True
# 398       False    False   False    False       True   False    False
#
# [399 rows x 27 columns]

# %%
dependent=dataset[['classification_yes']]

# %%
dependent
# Out:
#      classification_yes
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 394                   1
# 395                   1
# 396                   1
# 397                   1
# 398                   0
#
# [399 rows x 1 columns]

# %%
dataset["classification_yes"].value_counts()
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']] 
dependent=dataset[['classification_yes']]

# %%
independent.shape
# Out:
# (399, 27)

# %%
dependent
# Out:
#      classification_yes
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 394                   1
# 395                   1
# 396                   1
# 397                   1
# 398                   0
#
# [399 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[10,20,30,40]}
grid = GridSearchCV(SVC(probability=True),param_grid,refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')
#fitting the model for gridsearch
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 20, 30, 40],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(Y_test,grid_predictions,average='weighted')
print("The  f1_macro value for the best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The  f1_macro value for the best parameter {'C': 10, 'kernel': 'rbf'}: 0.9751481237656352

# %%
print(cm)
# Out:
# [[45  0]
#  [ 3 72]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        45
#            1       1.00      0.96      0.98        75
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.98      0.97       120
# weighted avg       0.98      0.97      0.98       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9994074074074074

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.008595      0.002790         0.004466        0.005510      10
# 1        0.012817      0.000761         0.007147        0.001920      10
# 2        0.008381      0.003192         0.007918        0.002377      10
# 3        0.006474      0.001017         0.006880        0.004563      10
# 4        0.004067      0.005585         0.014445        0.004222      20
# 5        0.013939      0.005653         0.007054        0.000703      20
# 6        0.012502      0.010106         0.006207        0.001442      20
# 7        0.011327      0.014234         0.006153        0.000856      20
# 8        0.005318      0.000423         0.007180        0.000650      30
# 9        0.008678      0.003780         0.007859        0.003803      30
# 10       0.013452      0.010381         0.006981        0.002061      30
# 11       0.016863      0.011089         0.007002        0.000444      30
# 12       0.015840      0.013330         0.005358        0.003319      40
# 13       0.009265      0.001697         0.005875        0.003138      40
# 14       0.006074      0.004017         0.006238        0.002762      40
# 15       0.008447      0.002555         0.006160        0.001270      40
#
#    param_kernel                          params  split0_test_score  \
# 0           rbf      {'C': 10, 'kernel': 'rbf'}           0.982221
# 1          poly     {'C': 10, 'kernel': 'poly'}           1.000000
# 2       sigmoid  {'C': 10, 'kernel': 'sigmoid'}           0.982221
# 3        linear   {'C': 10, 'kernel': 'linear'}           0.982221
# 4           rbf      {'C': 20, 'kernel': 'rbf'}           0.982221
# 5          poly     {'C': 20, 'kernel': 'poly'}           1.000000
# 6       sigmoid  {'C': 20, 'kernel': 'sigmoid'}           0.982221
# 7        linear   {'C': 20, 'kernel': 'linear'}           0.982221
# 8           rbf      {'C': 30, 'kernel': 'rbf'}           0.982221
# 9          poly     {'C': 30, 'kernel': 'poly'}           1.000000
# 10      sigmoid  {'C': 30, 'kernel': 'sigmoid'}           0.964286
# 11       linear   {'C': 30, 'kernel': 'linear'}           0.982221
# 12          rbf      {'C': 40, 'kernel': 'rbf'}           0.982221
# 13         poly     {'C': 40, 'kernel': 'poly'}           0.982221
# 14      sigmoid  {'C': 40, 'kernel': 'sigmoid'}           0.964286
# 15       linear   {'C': 40, 'kernel': 'linear'}           0.982221
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.982051           1.000000
# 1            0.982051           0.964286           0.982051
# 2            1.000000           0.946663           0.964286
# 3            0.946663           0.982221           0.964286
# 4            1.000000           0.982051           1.000000
# 5            0.982051           0.982051           1.000000
# 6            0.982221           0.982221           0.982051
# 7            0.946663           0.982221           0.964286
# 8            1.000000           0.982051           0.982051
# 9            0.982051           0.982051           1.000000
# 10           0.964286           0.982221           0.946663
# 11           0.946663           0.982221           0.964286
# 12           1.000000           0.982051           0.982051
# 13           1.000000           0.982051           0.982051
# 14           0.982051           0.982221           0.964572
# 15           0.946663           0.982221           0.964286
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.992854        0.008752                1
# 1            0.981894         0.982056        0.011294                9
# 2            1.000000         0.978634        0.020755               10
# 3            0.981894         0.971457        0.014190               13
# 4            1.000000         0.992854        0.008752                1
# 5            0.981894         0.989199        0.008819                5
# 6            1.000000         0.985743        0.007129                7
# 7            0.981894         0.971457        0.014190               13
# 8            1.000000         0.989265        0.008766                3
# 9            0.981894         0.989199        0.008819                5
# 10           1.000000         0.971491        0.018156               12
# 11           0.981894         0.971457        0.014190               13
# 12           1.000000         0.989265        0.008766                3
# 13           0.981894         0.985643        0.007179                8
# 14           1.000000         0.978626        0.013302               11
# 15           0.981894         0.971457        0.014190               13

# %%
b
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
print(cm)
# Out:
# [[45  0]
#  [ 5 70]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        45
#            1       1.00      0.93      0.97        75
#
#     accuracy                           0.96       120
#    macro avg       0.95      0.97      0.96       120
# weighted avg       0.96      0.96      0.96       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9666666666666667

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009551      0.003466         0.007533        0.001309
# 1       0.002395      0.000445         0.007062        0.001203
# 2       0.002792      0.000685         0.002331        0.001764
# 3       0.000233      0.000467         0.010898        0.005578
# 4       0.005760      0.004245         0.007318        0.000439
# 5       0.002366      0.000431         0.006357        0.000350
#
#   param_criterion param_splitter  \
# 0            gini           best
# 1            gini         random
# 2         entropy           best
# 3         entropy         random
# 4        log_loss           best
# 5        log_loss         random
#
#                                             params  split0_test_score  \
# 0        {'criterion': 'gini', 'splitter': 'best'}           0.982051
# 1      {'criterion': 'gini', 'splitter': 'random'}           0.928571
# 2     {'criterion': 'entropy', 'splitter': 'best'}           0.928571
# 3   {'criterion': 'entropy', 'splitter': 'random'}           0.982221
# 4    {'criterion': 'log_loss', 'splitter': 'best'}           0.928571
# 5  {'criterion': 'log_loss', 'splitter': 'random'}           0.982221
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.946663           0.894531           0.982051           0.981728
# 1           0.982221           0.982221           0.982221           0.963912
# 2           0.982051           0.876984           0.964286           0.945185
# 3           0.964286           0.964572           0.964572           0.963912
# 4           0.982051           0.876984           0.964286           0.945185
# 5           0.964286           0.894531           0.929144           0.963912
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.957405        0.034278                3
# 1         0.967829        0.020871                2
# 2         0.939415        0.036013                5
# 3         0.967913        0.007158                1
# 4         0.939415        0.036013                5
# 5         0.946819        0.031295                4

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
param_grid = {'criterion':['gini', 'entropy'],
               'max_features':['auto','sqrt','log2'],               
               'n_estimators':[100,10]}
grid = GridSearchCV(RandomForestClassifier(),param_grid,refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')
#fitting the model for gridsearch
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.98197781 0.96797441 0.97852739 0.97135116
#         nan        nan 0.97501594 0.97513301 0.98218175 0.97511452]
#   warnings.warn(
# C:\Python\Users\kavit\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 10]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_predictions)

from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
print(cm)
# Out:
# [[45  0]
#  [ 1 74]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        45
#            1       1.00      0.99      0.99        75
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9997037037037036

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002153      0.002472         0.000000        0.000000
# 1        0.001814      0.002740         0.000000        0.000000
# 2        0.200241      0.005348         0.013770        0.004582
# 3        0.027028      0.002938         0.005220        0.003453
# 4        0.192865      0.004545         0.012903        0.002406
# 5        0.022832      0.001459         0.007464        0.004150
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.000136      0.000271         0.000000        0.000000
# 8        0.203903      0.006410         0.012108        0.004937
# 9        0.021537      0.002461         0.010125        0.000043
# 10       0.177926      0.008964         0.006938        0.002109
# 11       0.024217      0.003611         0.008584        0.002328
#
#    param_criterion param_max_features param_n_estimators  \
# 0             gini               auto                100
# 1             gini               auto                 10
# 2             gini               sqrt                100
# 3             gini               sqrt                 10
# 4             gini               log2                100
# 5             gini               log2                 10
# 6          entropy               auto                100
# 7          entropy               auto                 10
# 8          entropy               sqrt                100
# 9          entropy               sqrt                 10
# 10         entropy               log2                100
# 11         entropy               log2                 10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 1   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           1.000000
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.964286
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           1.000000
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.982221
# 6   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 7   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...           1.000000
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.982051
# 10  {'criterion': 'entropy', 'max_features': 'log2...           1.000000
# 11  {'criterion': 'entropy', 'max_features': 'log2...           0.982221
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.963889           0.982221           0.982051
# 3            0.964286           0.947015           0.964286
# 4            0.982051           0.964572           0.964286
# 5            0.945469           0.947015           0.982051
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.982051           0.947015           0.964286
# 9            0.982051           0.929513           0.982051
# 10           0.982051           0.964572           0.964286
# 11           0.982051           0.947015           0.964286
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1                 NaN              NaN             NaN                9
# 2            0.981728         0.981978        0.011420                2
# 3            1.000000         0.967974        0.017354                8
# 4            0.981728         0.978527        0.013276                3
# 5            1.000000         0.971351        0.021520                7
# 6                 NaN              NaN             NaN                9
# 7                 NaN              NaN             NaN                9
# 8            0.981728         0.975016        0.017989                6
# 9            1.000000         0.975133        0.023846                4
# 10           1.000000         0.982182        0.015908                1
# 11           1.000000         0.975115        0.018026                5
